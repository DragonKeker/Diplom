# %% [markdown]
# # Правки

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/drive/MyDrive/upd_less30_MA_45.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Класс  Код_предмета      ЛогинОО  Балл_2019  \
# 0           0             0      4             2  sch01110001      11.83
# 1           1             1      4             2  sch01110003      13.37
# 2           2             2      4             2  sch01110004      12.90
# 3           3             3      4             2  sch01110005       9.61
# 4           4             4      4             2  sch01110006      12.77
#
#    Отметка_2019  Балл_%_2019  Отметка_%_2019  Балл_2020  ...       ввп  \
# 0          3.97        59.13           79.42      12.18  ...  309184.1
# 1          4.06        66.83           81.15      10.09  ...  309184.1
# 2          4.22        64.49           84.41       9.27  ...  309184.1
# 3          3.43        48.04           68.70       9.71  ...  309184.1
# 4          4.23        63.85           84.62       9.53  ...  309184.1
#
#    объекты  Индекс транспортной доступности: 0 - 1  \
# ...

# %%
data['ЛогинОО'].value_counts()
# Out:
# sch01110001    1
# sch55153231    1
# sch55153241    1
# sch55153240    1
# sch55153239    1
#               ..
# sch25153292    1
# sch25153291    1
# sch25153290    1
# sch25153289    1
# sch92126007    1
# Name: ЛогинОО, Length: 24535, dtype: int64

# %%
datam45 = pd.read_excel('/content/drive/MyDrive/datam45 (1).xlsx')
datar45 = pd.read_excel('/content/drive/MyDrive/datar45 (1).xlsx')
datar56 = pd.read_excel('/content/drive/MyDrive/datar56 (1).xlsx')

dataM45 = pd.read_csv('/content/drive/MyDrive/upd_less30_MA_45.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/openpyxl/worksheet/header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")

# %%
dataM45 = pd.read_csv('/content/drive/MyDrive/upd_less30_MA_45.csv')

# %%
dataM45.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Класс  Код_предмета      ЛогинОО  Балл_2019  \
# 0           0             0      4             2  sch01110001      11.83
# 1           1             1      4             2  sch01110003      13.37
# 2           2             2      4             2  sch01110004      12.90
# 3           3             3      4             2  sch01110005       9.61
# 4           4             4      4             2  sch01110006      12.77
#
#    Отметка_2019  Балл_%_2019  Отметка_%_2019  Балл_2020  ...       ввп  \
# 0          3.97        59.13           79.42      12.18  ...  309184.1
# 1          4.06        66.83           81.15      10.09  ...  309184.1
# 2          4.22        64.49           84.41       9.27  ...  309184.1
# 3          3.43        48.04           68.70       9.71  ...  309184.1
# 4          4.23        63.85           84.62       9.53  ...  309184.1
#
#    объекты  Индекс транспортной доступности: 0 - 1  \
# ...

# %%
data1M= dataM45.groupby(['region_code']).mean()

# %%
datam45.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Класс  Код_предмета      ЛогинОО  \
# 0           0             0               0      4             2  sch01110001
# 1           1             1               1      4             2  sch01110003
# 2           2             2               2      4             2  sch01110004
# 3           3             3               3      4             2  sch01110005
# 4           4             4               4      4             2  sch01110006
#
#    Балл_2019  Отметка_2019  Балл_%_2019  Отметка_%_2019  ...       ввп  \
# 0      11.83          3.97        59.13           79.42  ...  309184.1
# 1      13.37          4.06        66.83           81.15  ...  309184.1
# 2      12.90          4.22        64.49           84.41  ...  309184.1
# 3       9.61          3.43        48.04           68.70  ...  309184.1
# 4      12.77          4.23        63.85           84.62  ...  309184.1
#
#    объекты  Индекс транспортной доступности: 0 - 1  \
# ...

# %%
datam45['ЛогинОО'].value_counts(1)
# Out:
# sch01110001    0.000031
# sch55153270    0.000031
# sch55153284    0.000031
# sch55153283    0.000031
# sch55153282    0.000031
#                  ...
# sch25153489    0.000031
# sch25153488    0.000031
# sch25153487    0.000031
# sch25153486    0.000031
# sch92126007    0.000031
# Name: ЛогинОО, Length: 32628, dtype: float64

# %%
datam56 = pd.read_excel('/content/drive/MyDrive/datam56 (1).xlsx')
# Out:
# /usr/local/lib/python3.7/dist-packages/openpyxl/worksheet/header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")

# %%
datam45.head(1)
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Класс  Код_предмета      ЛогинОО  \
# 0           0             0               0      4             2  sch01110001
#
#    Балл_2019  Отметка_2019  Балл_%_2019  Отметка_%_2019  ...       ввп  \
# 0      11.83          3.97        59.13           79.42  ...  309184.1
#
#    объекты  Индекс транспортной доступности: 0 - 1  \
# 0        5                                    0.28
#
#    Валовой коэффициент охвата дошкольным образованием  \
# 0                                               67.7
#
#    ЧИСЛЕННОСТЬ ОБУЧАЮЩИХСЯ (1 – 4 классы)  \
# 0                                      22
#
#    ЧИСЛЕННОСТЬ ОБУЧАЮЩИХСЯ (5 – 9 классы)  \
# 0                                      20
#
#    ЧИСЛЕННОСТЬУЧИТЕЛЕЙ (тысяч человек)  № температурной зоны  \
# 0                                  3.6                     1
#
#    ОБУЧАЮЩИЕСЯ (тыс чел) обеспеченность учителями
# 0                   54.5                 0.066055
#
# [1 rows x 30 columns]

# %%
dataM45['Отметка_2020'].corr(dataM45['обеспеченность учителями'])
# Out:
# -0.05540516271751226

# %%
dataM45['Отметка_2020'].corr(dataM45['ввп'])
# Out:
# 0.0642868143867556

# %%
dataM45['Балл_2020'].corr(dataM45['объекты'])
# Out:
# 0.06058992667944069

# %%
dataM45['Балл_2020'].corr(dataM45['Отметка_2020'])
# Out:
# 0.9341339524792716

# %%
data1M.head(100)
# Out:
#                Unnamed: 0  Unnamed: 0.1  Класс  Код_предмета  Балл_2019  \
# region_code
# 1               56.000000     59.000000    4.0           2.0  12.145398
# 2              569.500000    644.332604    4.0           2.0  12.661389
# 3             1157.500000   1445.583969    4.0           2.0  11.319198
# 4             1332.500000   1690.431818    4.0           2.0  11.369545
# 5             1801.349112   2333.669822    4.0           2.0  11.642686
# ...                   ...           ...    ...           ...        ...
# 79           24111.500000  32133.500000    4.0           2.0  12.156667
# 83           24139.000000  32170.153846    4.0           2.0  11.609231
# 86           24265.500000  32311.037500    4.0           2.0  12.785542
# 89           24436.500000  32509.529412    4.0           2.0  12.567745
# 92           24518.500000  32596.500000    4.0           2.0  12.923226
#
#              Отметка_2019  Балл_%_2019  Отметка_%_2019  Балл_2020  \
# region_code
# ...

# %%
data1M['Балл_2020'].corr(data1M['объекты'])
# Out:
# 0.21763180371572974

# %%
data1M['Отметка_2020'].corr(data1M['Валовой коэффициент охвата дошкольным образованием'])
# Out:
# 0.5165337352509305

# %%
data1M['Отметка_2020'].corr(data1M['ввп'])
# Out:
# 0.050614071353078605

# %%
data1M['Отметка_2020'].corr(data1M['Индекс транспортной доступности: 0 - 1'])
# Out:
# 0.5575776423077339

# %%
data1M['Отметка_2020'].corr(data1M['ЧИСЛЕННОСТЬ ОБУЧАЮЩИХСЯ (1 – 4 классы)'])
# Out:
# 0.024437965680588515

# %%
data1M['Отметка_2020'].corr(data1M['ЧИСЛЕННОСТЬУЧИТЕЛЕЙ (тысяч человек)'])
# Out:
# 0.05077221228308086

# %%
data1M['Отметка_2020'].corr(data1M['№ температурной зоны'])
# Out:
# -0.08228169697417334

# %%
data1M['Отметка_2020'].corr(data1M['ОБУЧАЮЩИЕСЯ (тыс чел)'])
# Out:
# 0.07433327672780408

# %%
data1M['Отметка_2020'].corr(data1M['обеспеченность учителями'])
# Out:
# -0.15880432717082488

# %%
data1M.head(90)
# Out:
#                Unnamed: 0  Unnamed: 0.1  Класс  Код_предмета  Балл_2019  \
# region_code
# 1               56.000000     59.000000    4.0           2.0  12.145398
# 2              569.500000    644.332604    4.0           2.0  12.661389
# 3             1157.500000   1445.583969    4.0           2.0  11.319198
# 4             1332.500000   1690.431818    4.0           2.0  11.369545
# 5             1801.349112   2333.669822    4.0           2.0  11.642686
# ...                   ...           ...    ...           ...        ...
# 79           24111.500000  32133.500000    4.0           2.0  12.156667
# 83           24139.000000  32170.153846    4.0           2.0  11.609231
# 86           24265.500000  32311.037500    4.0           2.0  12.785542
# 89           24436.500000  32509.529412    4.0           2.0  12.567745
# 92           24518.500000  32596.500000    4.0           2.0  12.923226
#
#              Отметка_2019  Балл_%_2019  Отметка_%_2019  Балл_2020  \
# region_code
# ...

# %%
from google.colab import files

data1M.to_excel("data1M.xls")
files.download('data1M.xls')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#data0 = data1M[data1M['Отметка_2020'] == '0']['№ температурной зоны']
data2 = data1M[data1M['Отметка_2020'] == '2']['№ температурной зоны']
data3 = data1M[data1M['Отметка_2020'] == '3']['№ температурной зоны']
data4 = data1M[data1M['Отметка_2020'] == '4']['№ температурной зоны']
data5 = data1M[data1M['Отметка_2020'] == '5']['№ температурной зоны']
print(data5)
data = [ data2, data3, data4, data5]
fig = plt.figure(figsize =(18, 7))
ax = fig.add_axes([0, 0, 1, 1])
bp = ax.boxplot(data)
ax.set_xticklabels(['2','3','4','5'])
plt.show()
# Out:
# Series([], Name: № температурной зоны, dtype: float64)

# %%
data2 = data1M[data1M['Отметка_2020'] == 2 ]['Валовой коэффициент охвата дошкольным образованием']
data3 = data1M[data1M['Отметка_2020'] == 3 ]['Валовой коэффициент охвата дошкольным образованием'] 
data4 = data1M[data1M['Отметка_2020'] == 4 ]['Валовой коэффициент охвата дошкольным образованием'] 
data5 = data1M[data1M['Отметка_2020'] == 5 ]['Валовой коэффициент охвата дошкольным образованием']

data = [data2, data3, data4, data5]
fig = plt.figure(figsize =(10, 7))
ax = fig.add_axes([0, 0, 1, 1])
bp = ax.boxplot(data)
ax.set_xticklabels(['2','3','4','5'])
plt.show()

# %%
data2 = data1M[data1M['Отметка_2020'] == 2]['Валовой коэффициент охвата дошкольным образованием']
#data3 = dataM45[dataM45['Балл_2020'] > 5 and dataM45['Балл_2020'] <=9 ]['Валовой коэффициент охвата дошкольным образованием']
data3 = data1M[data1M['Отметка_2020'] == 3]['Валовой коэффициент охвата дошкольным образованием']  
#data4 = dataM45[dataM45['Балл_2020'] > 9 or dataM45['Балл_2020'] <=15]['Валовой коэффициент охвата дошкольным образованием'] 
data4 = data1M[data1M['Отметка_2020'] == 4]['Валовой коэффициент охвата дошкольным образованием'] 
data5 = data1M[data1M['Отметка_2020'] == 5]['Валовой коэффициент охвата дошкольным образованием']

data = [data2, data3, data4, data5]
fig = plt.figure(figsize =(18, 7))
ax = fig.add_axes([0, 0, 1, 1])
bp = ax.boxplot(data)
ax.set_xticklabels(['2','3','4','5'])
print(data5)
plt.show()
# Out:
# Series([], Name: Валовой коэффициент охвата дошкольным образованием, dtype: float64)

# %%
data2 = dataM45[dataM45['Балл_2020'] < 5 ]['Валовой коэффициент охвата дошкольным образованием']
#data3 = dataM45[dataM45['Балл_2020'] > 5 and dataM45['Балл_2020'] <=9 ]['Валовой коэффициент охвата дошкольным образованием']
data3 = dataM45[dataM45['Балл_2020'] == 7]['Валовой коэффициент охвата дошкольным образованием']  
#data4 = dataM45[dataM45['Балл_2020'] > 9 or dataM45['Балл_2020'] <=15]['Валовой коэффициент охвата дошкольным образованием'] 
data4 = dataM45[dataM45['Балл_2020'] == 12]['Валовой коэффициент охвата дошкольным образованием'] 
data5 = dataM45[dataM45['Балл_2020'] > 15 ]['Валовой коэффициент охвата дошкольным образованием']

data = [data2, data3, data4, data5]
fig = plt.figure(figsize =(18, 7))
ax = fig.add_axes([0, 0, 1, 1])
bp = ax.boxplot(data)
ax.set_xticklabels(['2','3','4','5'])
print(data5)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))
# 195      75.3
# 220      75.3
# 232      75.3
# 265      75.3
# 303      75.3
#          ...
# 24240    76.0
# 24288    76.0
# 24438    82.6
# 24473    63.3
# 24531    63.3
# Name: Валовой коэффициент охвата дошкольным образованием, Length: 247, dtype: float64

# %%
data2 = dataM45[dataM45['Отметка_2020'] == 2 ]['Валовой коэффициент охвата дошкольным образованием']
data3 = dataM45[dataM45['Отметка_2020'] == 3 ]['Валовой коэффициент охвата дошкольным образованием'] 
data4 = dataM45[dataM45['Отметка_2020'] == 4 ]['Валовой коэффициент охвата дошкольным образованием'] 
data5 = dataM45[dataM45['Отметка_2020'] == 5 ]['Валовой коэффициент охвата дошкольным образованием']

data = [data2, data3, data4, data5]
fig = plt.figure(figsize =(18, 7))
ax = fig.add_axes([0, 0, 1, 1])
bp = ax.boxplot(data)
ax.set_xticklabels(['2','3','4','5'])
print(data5)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))
# 753      75.3
# 756      75.3
# 1697     32.0
# 1785     32.0
# 2177     32.0
# 3865     71.3
# 10287    74.3
# 13505    76.6
# 13659    76.6
# 13665    76.6
# 13677    76.6
# 13997    71.3
# 14898    79.7
# 16684    73.2
# 17762    79.0
# 19057    68.4
# 20035    67.2
# 21667    70.1
# 21920    75.4
# 22886    84.3
# 23470    82.5
# Name: Валовой коэффициент охвата дошкольным образованием, dtype: float64

# %%
data0 = datam45[datam45['Отметка_2020'] == 0]['ввп']
data2 = datam45[datam45['Отметка_2020'] == 2]['ввп']
data3 = datam45[datam45['Отметка_2020'] == 3]['ввп']
data4 = datam45[datam45['Отметка_2020'] == 4]['ввп']
data5 = datam45[datam45['Отметка_2020'] == 5]['ввп']
data = [data0, data2, data3, data4, data5]
fig = plt.figure(figsize =(10, 7))
ax = fig.add_axes([0, 0, 1, 1])
bp = ax.boxplot(data)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %%
data0 = datam45[datam45['Отметка_2020'] == 0]['объекты']
data2 = datam45[datam45['Отметка_2020'] == 2]['объекты']
data3 = datam45[datam45['Отметка_2020'] == 3]['объекты']
data4 = datam45[datam45['Отметка_2020'] == 4]['объекты']
data5 = datam45[datam45['Отметка_2020'] == 5]['объекты']
data = [data0, data2, data3, data4, data5]
fig = plt.figure(figsize =(10, 7))
ax = fig.add_axes([0, 0, 1, 1])
bp = ax.boxplot(data)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %%
#data0 = datam45[datam45['Отметка_2020'] == 0]['Балл_2020']
data2 = data1M[data1M['Отметка_2020'] == 2]['Балл_2020']
data3 = datam45[datam45['Отметка_2020'] == 3]['Балл_2020']
data4 = datam45[datam45['Отметка_2020'] == 4]['Балл_2020']
data5 = datam45[datam45['Отметка_2020'] == 5]['Балл_2020']
data = [#data0,
        data2, data3, data4, data5]
fig = plt.figure(figsize =(10, 7))
ax = fig.add_axes([0, 0, 1, 1])
bp = ax.boxplot(data)
ax.set_xticklabels(['2','3','4','5'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %%
 #plt.plot(datam45['Валовой коэффициент охвата дошкольным образованием'],datam45['Отметка_2020'])
 boxplot = datam45.boxplot(column=['Валовой коэффициент охвата дошкольным образованием', 'Отметка_2020'])

# %%
datam45 = pd.read_csv('/content/drive/MyDrive/data4_5M_un(f).csv')
datam56 = pd.read_csv('/content/drive/MyDrive/data5_6M_un(f).csv')
datar45 = pd.read_csv('/content/drive/MyDrive/data4_5R_un(f).csv')
datar56 = pd.read_csv('/content/drive/MyDrive/data5_6R_un(f).csv')
tr = pd.read_excel('/content/drive/MyDrive/Т_Р.xlsx')
ot = pd.read_excel('/content/drive/MyDrive/О_Т.xlsx')

# %%
datar45 = datar45.drop(['№ температурной зоны'], axis=1)
datar56 = datar56.drop(['№ температурной зоны'], axis=1)
datam45 = datam45.drop(['№ температурной зоны'], axis=1)
datam56 = datam56.drop(['№ температурной зоны'], axis=1)

# %%
datar45.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Класс  Код_предмета      ЛогинОО  Балл_2019  \
# 0           0             0      4             1  sch01110001      26.92
# 1           1             1      4             1  sch01110003      25.38
# 2           2             2      4             1  sch01110004      22.54
# 3           3             3      4             1  sch01110005      25.22
# 4           4             4      4             1  sch01110006      25.42
#
#    Отметка_2019  Балл_%_2019  Отметка_%_2019  Балл_2020  ...  \
# 0          3.94        70.85           78.77      23.15  ...
# 1          3.64        66.78           72.83      21.46  ...
# 2          3.51        59.31           70.15      19.34  ...
# 3          3.70        66.37           74.07      21.43  ...
# 4          3.83        66.89           76.67      18.17  ...
#
#    Дельта_Отметка_%  region_code             названиерегиона       ввп  \
# 0             -7.01            1  Республика Адыгея (Адыгея)  309184.1
# ...

# %%
datar45 = pd.merge(datar45, tr, on='region_code', how='inner')
datar56 = pd.merge(datar56, tr, on='region_code', how='inner')
datam45 = pd.merge(datam45, tr, on='region_code', how='inner')
datam56 = pd.merge(datam56, tr, on='region_code', how='inner')

# %%
datar45 = pd.merge(datar45, ot, on='region_code', how='inner')
datar56 = pd.merge(datar56, ot, on='region_code', how='inner')
datam45 = pd.merge(datam45, ot, on='region_code', how='inner')
datam56 = pd.merge(datam56, ot, on='region_code', how='inner')

# %%
datar45.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Класс  Код_предмета      ЛогинОО  Балл_2019  \
# 0           0             0      4             1  sch01110001      26.92
# 1           1             1      4             1  sch01110003      25.38
# 2           2             2      4             1  sch01110004      22.54
# 3           3             3      4             1  sch01110005      25.22
# 4           4             4      4             1  sch01110006      25.42
#
#    Отметка_2019  Балл_%_2019  Отметка_%_2019  Балл_2020  ...  \
# 0          3.94        70.85           78.77      23.15  ...
# 1          3.64        66.78           72.83      21.46  ...
# 2          3.51        59.31           70.15      19.34  ...
# 3          3.70        66.37           74.07      21.43  ...
# 4          3.83        66.89           76.67      18.17  ...
#
#               названиерегиона       ввп  объекты  \
# 0  Республика Адыгея (Адыгея)  309184.1      5.0
# 1  Республика Адыгея (Адыгея)  309184.1      5.0
# ...

# %%
import numpy as np
#datar45 = pd.merge(datar45, ot, on='region_code', how='inner')
#datar56 = pd.merge(datar56, ot, on='region_code', how='inner')
#datam45 = pd.merge(datam45, ot, on='region_code', how='inner')
#datam56 = pd.merge(datam56, ot, on='region_code', how='inner')

# %%
datar45['обеспеченность учителями'] = np.where(datar45['ОБУЧАЮЩИЕСЯ (тыс чел)'] < 1, datar45['ОБУЧАЮЩИЕСЯ (тыс чел)'], datar45['ЧИСЛЕННОСТЬУЧИТЕЛЕЙ (тысяч человек)']/datar45['ОБУЧАЮЩИЕСЯ (тыс чел)'])
datar56['обеспеченность учителями'] = np.where(datar56['ОБУЧАЮЩИЕСЯ (тыс чел)'] < 1, datar56['ОБУЧАЮЩИЕСЯ (тыс чел)'], datar56['ЧИСЛЕННОСТЬУЧИТЕЛЕЙ (тысяч человек)']/datar56['ОБУЧАЮЩИЕСЯ (тыс чел)'])
datam45['обеспеченность учителями'] = np.where(datam45['ОБУЧАЮЩИЕСЯ (тыс чел)'] < 1, datam45['ОБУЧАЮЩИЕСЯ (тыс чел)'], datam45['ЧИСЛЕННОСТЬУЧИТЕЛЕЙ (тысяч человек)']/datam45['ОБУЧАЮЩИЕСЯ (тыс чел)'])
datam56['обеспеченность учителями'] = np.where(datam56['ОБУЧАЮЩИЕСЯ (тыс чел)'] < 1, datam56['ОБУЧАЮЩИЕСЯ (тыс чел)'], datam56['ЧИСЛЕННОСТЬУЧИТЕЛЕЙ (тысяч человек)']/datam56['ОБУЧАЮЩИЕСЯ (тыс чел)'])

# %%
datar45.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Класс  Код_предмета      ЛогинОО  Балл_2019  \
# 0           0             0      4             1  sch01110001      26.92
# 1           1             1      4             1  sch01110003      25.38
# 2           2             2      4             1  sch01110004      22.54
# 3           3             3      4             1  sch01110005      25.22
# 4           4             4      4             1  sch01110006      25.42
#
#    Отметка_2019  Балл_%_2019  Отметка_%_2019  Балл_2020  ...       ввп  \
# 0          3.94        70.85           78.77      23.15  ...  309184.1
# 1          3.64        66.78           72.83      21.46  ...  309184.1
# 2          3.51        59.31           70.15      19.34  ...  309184.1
# 3          3.70        66.37           74.07      21.43  ...  309184.1
# 4          3.83        66.89           76.67      18.17  ...  309184.1
#
#    объекты  Индекс транспортной доступности: 0 - 1  \
# ...

# %%
print(datar45.isna().sum())
# Out:
# Unnamed: 0                                            0
# Unnamed: 0.1                                          0
# Класс                                                 0
# Код_предмета                                          0
# ЛогинОО                                               0
# Балл_2019                                             0
# Отметка_2019                                          0
# Балл_%_2019                                           0
# Отметка_%_2019                                        0
# Балл_2020                                             0
# Отметка_2020                                          0
# Балл_%_2020                                           0
# Отметка_%_2020                                        0
# Дельта_Балл                                           0
# Дельта_Балл_%                                         0
# Дельта_Отметка                                        0
# Дельта_Отметка_%                                      0
# ...

# %%
datar45.to_excel("datar45.xls")
datar56.to_excel("datar56.xls")
datam45.to_excel("datam45.xls")
datam56.to_excel("datam56.xls")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   """Entry point for launching an IPython kernel.
# ...

# %%
from google.colab import files
files.download('datar45.xls')
files.download('datar56.xls')
files.download('datam45.xls')
files.download('datam56.xls')

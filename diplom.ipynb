# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-2-d5df0069828e> in <module>
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#     104       timeout_ms=timeout_ms,
#     105       ephemeral=True,
# --> 106       readonly=readonly)
#     107
#     108
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     123   if ephemeral:
#     124     _message.blocking_request(
# --> 125         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None)
#     126
#     127   mountpoint = _os.path.expanduser(mountpoint)
#
# ...

# %% [markdown]
# #Очистка данных

# %%
data = pd.read_csv('/content/drive/MyDrive/pupils_ruma456_2019_2020.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (0,1,3,4,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
data = data[data['Отметка'] != ' ']

# %%
data[['Балл']] = data[['Балл']].apply(pd.to_numeric)##количественные 

data[['Класс', 'Код_предмета', 'Код_ученика', 'Отметка', 'Year']] = data[['Класс', 'Код_предмета', 'Код_ученика', 'Отметка', 'Year']].astype(str)#качественные

# %%
data.head()
# Out:
#   Класс Код_предмета      ЛогинОО Код_ученика  Балл Отметка  Year
# 0     4            2  sch01110001        4001    11       4  2019
# 1     4            2  sch01110001        4002    18       5  2019
# 2     4            2  sch01110001        4003     9       3  2019
# 3     4            2  sch01110001        4004    11       4  2019
# 4     4            2  sch01110001        4005     8       3  2019

# %%
data['ЛогинОО'].value_counts()
# Out:
# sch72120397    4666
# sch23133988    4630
# sch23133985    4544
# sch72123046    4171
# sch72123048    3395
#                ...
# sch03136025       1
# sch05153509       1
# sch66163320       1
# sch55156133       1
# sch70103089       1
# Name: ЛогинОО, Length: 39391, dtype: int64

# %%
data[data['Класс'] == 'Класс'].head()
# Out:
# Empty DataFrame
# Columns: [Класс, Код_предмета, ЛогинОО, Код_ученика, Балл, Отметка, Year]
# Index: []

# %%
data['Балл'].value_counts()
# Out:
# 11    559992
# 14    554918
# 12    532355
# 7     510728
# 13    504913
#        ...
# 0       1547
# 43      1152
# 44       770
# 45       331
#            3
# Name: Балл, Length: 93, dtype: int64

# %%
data['Отметка'].value_counts()
# Out:
# 4    4212508
# 3    3470886
# 5    2090689
# 2    1200287
# 0     246976
# Name: Отметка, dtype: int64

# %%
data['Код_ученика'].unique()
# Out:
# array([4001, 4002, 4003, ..., 50788, 50794, 50795], dtype=object)

# %%
data[data['Отметка'] == '0'].head(10000)
# Out:
#         Класс Код_предмета      ЛогинОО Код_ученика  Балл Отметка  Year
# 1549526     5            2  sch01110062        5001     8       0  2019
# 1549527     5            2  sch01110062        5002    17       0  2019
# 1549528     5            2  sch01110062        5003    12       0  2019
# 1549529     5            2  sch01110062        5004     7       0  2019
# 1549530     5            2  sch01110062        5005    11       0  2019
# ...       ...          ...          ...         ...   ...     ...   ...
# 1691631     5            2  sch11113206        5060     9       0  2019
# 1691632     5            2  sch11113206        5061     7       0  2019
# 1691633     5            2  sch11113206        5062    14       0  2019
# 1691634     5            2  sch11113206        5063     7       0  2019
# 1691635     5            2  sch11113206        5064     7       0  2019
#
# [10000 rows x 7 columns]

# %%
data['Отметка'].unique()
# Out:
# array(['4', '5', '3', '2', '0'], dtype=object)

# %%
data[data['Отметка'] == "4"].describe()
#describe - описательный анализ
#статистика по людям которые получили 4
#mean - среднее значение атрибута (21)
# Out:
#                Балл
# count  4.212508e+06
# mean   2.130000e+01
# std    9.405378e+00
# min    8.000000e+00
# 25%    1.200000e+01
# 50%    2.400000e+01
# 75%    3.000000e+01
# max    3.800000e+01

# %%
data[data['Отметка'] == "3"].describe()
'''count - кол-во записей по 
mean - среднее значение атрибута (15)
std - корень дисперсии выборки (можно сравнить разброс выборки чем больше тем больше разброс чем меньше тем ближе к ср знач)
min - самое мал значение баллов
50%- медиана
25%
75% квартили
max - максимум
мы проверили что на данный момент нельзя сделать однозначное отображение балла в оценку
'''
# Out:
# 'count - кол-во записей по \nmean - среднее значение атрибута (15)\nstd - корень дисперсии выборки (можно сравнить разброс выборки чем больше тем больше разброс чем меньше тем ближе к ср знач)\nmin - самое мал значение баллов\n50%- медиана\n25%\n75% квартили\nmax - максимум\nмы проверили что на данный момент нельзя сделать однозначное отображение балла в оценку\n'

# %%
data[(data['Отметка'] == "4") & (data['Код_предмета'] == "2") ].describe()
# Out:
#                Балл
# count  2.065341e+06
# mean   1.213241e+01
# std    1.312786e+00
# min    8.000000e+00
# 25%    1.100000e+01
# 50%    1.200000e+01
# 75%    1.300000e+01
# max    1.400000e+01

# %%
data[(data['Отметка'] == "3") & (data['Код_предмета'] == "2") ].describe()
# Out:
#                Балл
# count  1.556410e+06
# mean   8.010509e+00
# std    1.127489e+00
# min    5.000000e+00
# 25%    7.000000e+00
# 50%    8.000000e+00
# 75%    9.000000e+00
# max    1.000000e+01

# %%
data['Отметка'].value_counts()
# Out:
# 4    4212508
# 3    3470886
# 5    2090689
# 2    1200287
# 0     246976
# Name: Отметка, dtype: int64

# %%
data.loc[(data['Отметка'] == "4") & (data['Код_предмета'] == "2") & (data['Балл'] == "0")]
# Out:
# Empty DataFrame
# Columns: [Класс, Код_предмета, ЛогинОО, Код_ученика, Балл, Отметка, Year]
# Index: []

# %%
data.loc[(data['Отметка'] == "3") & (data['Код_предмета'] == "2")]
# Out:
#         Класс Код_предмета      ЛогинОО Код_ученика  Балл Отметка  Year
# 2           4            2  sch01110001        4003     9       3  2019
# 4           4            2  sch01110001        4005     8       3  2019
# 7           4            2  sch01110001        4008     8       3  2019
# 9           4            2  sch01110001        4010     7       3  2019
# 13          4            2  sch01110001        4015     7       3  2019
# ...       ...          ...          ...         ...   ...     ...   ...
# 8587090     6            2  sch78186118       60119     8       3  2020
# 8587091     6            2  sch78186118       60121     9       3  2020
# 8587095     6            2  sch78186118       60125     9       3  2020
# 8587096     6            2  sch78186118       60126     7       3  2020
# 8587098     6            2  spo66160020       60001     8       3  2020
#
# [1556410 rows x 7 columns]

# %%
def get_slice(x):
  return x[3:5]

# %%
get_slice([1,2,3,4,5,5])
# Out:
# [4, 5]

# %%
data['region_code'] = data['ЛогинОО'].apply(get_slice)

# %%
data.head(10000000000000000000000000000000000000000000000)
# Out:
#          Класс Код_предмета      ЛогинОО Код_ученика Балл Отметка  Year  \
# 0            4            2  sch01110001        4001   11       4  2019
# 1            4            2  sch01110001        4002   18       5  2019
# 2            4            2  sch01110001        4003    9       3  2019
# 3            4            2  sch01110001        4004   11       4  2019
# 4            4            2  sch01110001        4005    8       3  2019
# ...        ...          ...          ...         ...  ...     ...   ...
# 11221344     5            1  sch87176023       50212   10       2  2020
# 11221345     5            1  sch87176023       50213   21       3  2020
# 11221346     5            1  sch87176023       50214   21       3  2020
# 11221347     5            1  sch87176023       50216   21       3  2020
# 11221348     5            1  sch87176023       50219   31       4  2020
#
#          region_code
# 0                 01
# 1                 01
# 2                 01
# ...

# %%
data.loc[(data['region_code'] == '90') ]
# Out:
#          Класс Код_предмета      ЛогинОО Код_ученика Балл Отметка  Year  \
# 1541580      4            2  sch90103001        4001    9       3  2019
# 1541581      4            2  sch90103001        4002   16       5  2019
# 1541582      4            2  sch90103001        4003   13       4  2019
# 1541583      4            2  sch90103001        4004   17       5  2019
# 1541584      4            2  sch90103001        4005   13       4  2019
# ...        ...          ...          ...         ...  ...     ...   ...
# 11205966     5            1  sch90103046       50013   36       5  2020
# 11205967     5            1  sch90106012       50001   20       3  2020
# 11205968     5            1  sch90106012       50002   28       4  2020
# 11205969     5            1  sch90106012       50003   29       4  2020
# 11205970     5            1  sch90106012       50004   26       4  2020
#
#          region_code
# 1541580           90
# 1541581           90
# 1541582           90
# ...

# %%
data[['region_code']] = data[['region_code']].apply(pd.to_numeric)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "D "
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-36388d558b79> in <module>()
# ----> 1 data[['region_code']] = data[['region_code']].apply(pd.to_numeric)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8738             kwargs=kwargs,
#    8739         )
# -> 8740         return op.apply()
#    8741
#    8742     def applymap(
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/apply.py in apply(self)
#     686             return self.apply_raw()
#     687
# ...

# %%
Контекстные_данные = pd.read_excel('/content/drive/MyDrive/Конт_данныеОО.xlsx')

# %%
Контекстные_данные.head()
# Out:
#       Логин ОО       Где расположена образовательная организация?  \
# 0     Логин ОО                                                NaN
# 1  sch05153602  4. Населенный пункт сельского типа (село, хуто...
# 2  sch05153601  4. Населенный пункт сельского типа (село, хуто...
# 3  sch05153598  4. Населенный пункт сельского типа (село, хуто...
# 4  sch05153594  4. Населенный пункт сельского типа (село, хуто...
#
#   Наименование населенного пункта Размер населенного пункта  \
# 0                             NaN                       NaN
# 1                   село Шумлелик   1. Менее 1 тыс. человек
# 2               Червленные-буруны       2. 1–5 тыс. человек
# 3                        Ортатюбе          3. 5–10 тыс. чел
# 4                           Кумли   1. Менее 1 тыс. человек
#
#   ОО является специальной (коррекционной)  \
# 0                                     NaN
# 1                                     Нет
# 2                                      Да
# ...

# %%
Контекстные_данные['Размер населенного пункта'].unique()
# Out:
# array([nan, '1. Менее 1 тыс. человек', '2. 1–5 тыс. человек',
#        '3. 5–10 тыс. чел', '6. 100–450 тыс. человек',
#        '4. 10–50 тыс. человек', '5. 50–100 тыс. человек',
#        '8. Более 680 тыс. человек', '7. 450–680 тыс. человек'],
#       dtype=object)

# %%
Контекстные_данные.rename(columns={'Логин ОО':'login', 
                      'Где расположена образовательная организация?':'location_type', 
                      'Наименование населенного пункта':'location', 
                      'Размер населенного пункта':'pop_size', 
                      'ОО является специальной (коррекционной)':'special_flg',
                      'Количество обучающихся в ОО (в сумме по всем классам)':'student_cnt'},
            inplace=True)

# %%
Контекстные_данные = Контекстные_данные[1:]
#костыль

# %%
Контекстные_данные.head()
# Out:
#          login                                      location_type  \
# 1  sch05153602  4. Населенный пункт сельского типа (село, хуто...
# 2  sch05153601  4. Населенный пункт сельского типа (село, хуто...
# 3  sch05153598  4. Населенный пункт сельского типа (село, хуто...
# 4  sch05153594  4. Населенный пункт сельского типа (село, хуто...
# 5  sch05153592  4. Населенный пункт сельского типа (село, хуто...
#
#             location                 pop_size special_flg student_cnt
# 1      село Шумлелик  1. Менее 1 тыс. человек         Нет         207
# 2  Червленные-буруны      2. 1–5 тыс. человек          Да         287
# 3           Ортатюбе         3. 5–10 тыс. чел         Нет         110
# 4              Кумли  1. Менее 1 тыс. человек         Нет          96
# 5            Карагас      2. 1–5 тыс. человек         Нет         220

# %%
Контекстные_данные['special_flg'].value_counts()
# Out:
# Нет    35995
# Да       795
# нет      108
# да         2
# Name: special_flg, dtype: int64

# %%
Контекстные_данные['special_flg'] = Контекстные_данные['special_flg'].str.upper()

# %%
Контекстные_данные['special_flg'].value_counts()
# Out:
# НЕТ    36103
# ДА       797
# Name: special_flg, dtype: int64

# %%
Контекстные_данные[Контекстные_данные['student_cnt']=="Руэм"].value_counts()
# Out:
# login        location_type                                                    location  pop_size             special_flg  student_cnt
# sch12123065  4. Населенный пункт сельского типа (село, хутор, деревня и пр.)  Руэм      2. 1–5 тыс. человек  НЕТ          Руэм           1
# dtype: int64

# %%
Контекстные_данные[['student_cnt']] = Контекстные_данные[['student_cnt']].apply(pd.to_numeric)##количественные
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "Руэм"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-83613f78906f> in <module>()
# ----> 1 Контекстные_данные[['student_cnt']] = Контекстные_данные[['student_cnt']].apply(pd.to_numeric)##количественные
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8738             kwargs=kwargs,
#    8739         )
# -> 8740         return op.apply()
#    8741
#    8742     def applymap(
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/apply.py in apply(self)
# ...

# %%
ob = pd.read_excel('/content/drive/MyDrive/OBSchAYa.xlsx')

# %%
ob.head(100)
# Out:
#                                       названиерегиона  регион        ввп  \
# 0                          Республика Адыгея (Адыгея)     1.0   309184.1
# 1                             Республика Башкортостан     2.0   425161.0
# 2                                  Республика Бурятия     3.0   307558.8
# 3                                    Республика Алтай     4.0   283451.4
# 4                                 Республика Дагестан     5.0   239640.7
# ..                                                ...     ...        ...
# 80  Ненецкий автономный округ (Архангельская область)    83.0  5206287.1
# 81  Ханты-Мансийский автономный округ - Югра (Тюме...    86.0  1994630.3
# 82                         Чукотский автономный округ    87.0  2404271.2
# 83  Ямало-Ненецкий автономный округ (Тюменская обл...    89.0  5072483.6
# 84            Город федерального значения Севастополь    92.0   295304.9
#
#     объекты
# 0       5.0
# 1      11.0
# 2      42.0
# 3       7.0
# 4      29.0
# ...

# %%
ob.tail(30)
# Out:
#                                       названиерегиона  регион        ввп  \
# 55                               Оренбургская область    56.0   538971.9
# 56                                  Орловская область    57.0   390170.2
# 57                                 Пензенская область    58.0   379820.4
# 58                                      Пермский край    59.0   541930.2
# 59                                  Псковская область    60.0   325659.6
# 60                                 Ростовская область    61.0   403949.1
# 61                                  Рязанская область    62.0   412845.1
# 62                                  Самарская область    63.0   505093.4
# 63                                Саратовская область    64.0   358480.4
# 64                                Сахалинская область    65.0  2059206.5
# 65                               Свердловская область    66.0   588270.0
# 66                                 Смоленская область    67.0   386274.8
# ...

# %%
ob[['регион']] = ob[['регион']].apply(pd.to_numeric)

# %%
ob.tail(30)
# Out:
#                                       названиерегиона  регион        ввп  \
# 55                               Оренбургская область    56.0   538971.9
# 56                                  Орловская область    57.0   390170.2
# 57                                 Пензенская область    58.0   379820.4
# 58                                      Пермский край    59.0   541930.2
# 59                                  Псковская область    60.0   325659.6
# 60                                 Ростовская область    61.0   403949.1
# 61                                  Рязанская область    62.0   412845.1
# 62                                  Самарская область    63.0   505093.4
# 63                                Саратовская область    64.0   358480.4
# 64                                Сахалинская область    65.0  2059206.5
# 65                               Свердловская область    66.0   588270.0
# 66                                 Смоленская область    67.0   386274.8
# ...

# %%
tr = pd.read_excel('/content/drive/MyDrive/трд1.xlsx')

# %%
tr.head(100)
# Out:
#                              Регион  Транспортная доступность  Ранг  \
# 0                     Тверская обл.                     18.01   2.0
# 1                    Калужская обл.                     17.55   3.0
# 2                 Владимирская обл.                     17.47   4.0
# 3                    Рязанская обл.                     17.34   5.0
# 4                     Тульская обл.                     17.06   6.0
# ..                              ...                       ...   ...
# 81               Московская область                       NaN   NaN
# 82                        г. Москва                       NaN   NaN
# 83                  Республика Крым                       NaN   NaN
# 84       Чукотский автономный округ                       NaN   NaN
# 85  ОУ, находящиеся за пределами РФ                       NaN   NaN
#
#     Индекс транспортной доступности: 0 - 1  reg_num
# 0                                     0.59        69
# ...

# %%
tr[['reg_num ']] = tr[['reg_num ']].apply(pd.to_numeric)

# %%
tr.head(1000)
# Out:
#                              Регион  Транспортная доступность  Ранг  \
# 0                     Тверская обл.                     18.01   2.0
# 1                    Калужская обл.                     17.55   3.0
# 2                 Владимирская обл.                     17.47   4.0
# 3                    Рязанская обл.                     17.34   5.0
# 4                     Тульская обл.                     17.06   6.0
# ..                              ...                       ...   ...
# 81               Московская область                       NaN   NaN
# 82                        г. Москва                       NaN   NaN
# 83                  Республика Крым                       NaN   NaN
# 84       Чукотский автономный округ                       NaN   NaN
# 85  ОУ, находящиеся за пределами РФ                       NaN   NaN
#
#     Индекс транспортной доступности: 0 - 1  reg_num
# 0                                     0.59        69
# ...

# %%
ob.rename(columns={'регион':'region_code',},
            inplace=True)
tr.rename(columns={'reg_num ':'region_code',},
            inplace=True)

# %%
data_un = pd.merge(ob, tr, on='region_code', how='inner')

# %%
data_un.head(100000000000)
# Out:
#                                       названиерегиона  region_code        ввп  \
# 0                          Республика Адыгея (Адыгея)          1.0   309184.1
# 1                             Республика Башкортостан          2.0   425161.0
# 2                                  Республика Бурятия          3.0   307558.8
# 3                                    Республика Алтай          4.0   283451.4
# 4                                 Республика Дагестан          5.0   239640.7
# ..                                                ...          ...        ...
# 80  Ненецкий автономный округ (Архангельская область)         83.0  5206287.1
# 81  Ханты-Мансийский автономный округ - Югра (Тюме...         86.0  1994630.3
# 82                         Чукотский автономный округ         87.0  2404271.2
# 83  Ямало-Ненецкий автономный округ (Тюменская обл...         89.0  5072483.6
# 84            Город федерального значения Севастополь         92.0   295304.9
#
# ...

# %%
data_un = data_un.drop(['Регион','Ранг',	'Транспортная доступность'], axis=1)

# %%
data_un.to_csv("data_un.csv")

# %%
from google.colab import files
files.download('data_un.csv')

# %%
do = pd.read_excel('/content/drive/MyDrive/Д_О.xlsx')
cho = pd.read_excel('/content/drive/MyDrive/С_Ч_О.xlsx')
chu = pd.read_excel('/content/drive/MyDrive/Ч_У.xlsx')
temr = pd.read_excel('/content/drive/MyDrive/Т_Р.xlsx')

# %%
data_un_ = pd.merge(data_un, do, on='region_code', how='inner')
data_un__ = pd.merge(data_un_, cho, on='region_code', how='inner')
data_un___ = pd.merge(data_un__, chu, on='region_code', how='inner')
data_un____ = pd.merge(data_un___, temr, on='region_code', how='inner')

# %%
data_un____.head(1000)
# Out:
#                                       названиерегиона  region_code        ввп  \
# 0                          Республика Адыгея (Адыгея)          1.0   309184.1
# 1                             Республика Башкортостан          2.0   425161.0
# 2                                  Республика Бурятия          3.0   307558.8
# 3                                    Республика Алтай          4.0   283451.4
# 4                                 Республика Дагестан          5.0   239640.7
# ..                                                ...          ...        ...
# 80  Ненецкий автономный округ (Архангельская область)         83.0  5206287.1
# 81  Ханты-Мансийский автономный округ - Югра (Тюме...         86.0  1994630.3
# 82                         Чукотский автономный округ         87.0  2404271.2
# 83  Ямало-Ненецкий автономный округ (Тюменская обл...         89.0  5072483.6
# 84            Город федерального значения Севастополь         92.0   295304.9
#
# ...

# %%
data_un____ = data_un____.drop(['Регион','Ранг',	'Транспортная доступность'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-64-516d413adfae> in <module>()
# ----> 1 data_un____ = data_un____.drop(['Регион','Ранг',        'Транспортная доступность'], axis=1)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
data_un____.head(1000)
# Out:
#                                       названиерегиона  region_code        ввп  \
# 0                          Республика Адыгея (Адыгея)          1.0   309184.1
# 1                             Республика Башкортостан          2.0   425161.0
# 2                                  Республика Бурятия          3.0   307558.8
# 3                                    Республика Алтай          4.0   283451.4
# 4                                 Республика Дагестан          5.0   239640.7
# ..                                                ...          ...        ...
# 80  Ненецкий автономный округ (Архангельская область)         83.0  5206287.1
# 81  Ханты-Мансийский автономный округ - Югра (Тюме...         86.0  1994630.3
# 82                         Чукотский автономный округ         87.0  2404271.2
# 83  Ямало-Ненецкий автономный округ (Тюменская обл...         89.0  5072483.6
# 84            Город федерального значения Севастополь         92.0   295304.9
#
# ...

# %%
data_un2 = pd.merge(data, data_un, on='region_code', how='inner')

# %%
data_un2.head()
# Out:
#   Класс Код_предмета      ЛогинОО Код_ученика  Балл Отметка  Year  \
# 0     4            2  sch01110001        4001    11       4  2019
# 1     4            2  sch01110001        4002    18       5  2019
# 2     4            2  sch01110001        4003     9       3  2019
# 3     4            2  sch01110001        4004    11       4  2019
# 4     4            2  sch01110001        4005     8       3  2019
#
#    region_code             названиерегиона       ввп  объекты  \
# 0            1  Республика Адыгея (Адыгея)  309184.1      5.0
# 1            1  Республика Адыгея (Адыгея)  309184.1      5.0
# 2            1  Республика Адыгея (Адыгея)  309184.1      5.0
# 3            1  Республика Адыгея (Адыгея)  309184.1      5.0
# 4            1  Республика Адыгея (Адыгея)  309184.1      5.0
#
#    Индекс транспортной доступности: 0 - 1
# 0                                    0.28
# 1                                    0.28
# 2                                    0.28
# ...

# %%
data_un2.to_excel("output3.xlsx")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-f7438dfea620> in <module>()
# ----> 1 data_un2.to_excel("output3.xlsx")
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2289             freeze_panes=freeze_panes,
#    2290             engine=engine,
# -> 2291             storage_options=storage_options,
#    2292         )
#    2293
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/formats/excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     822         if num_rows > self.max_rows or num_cols > self.max_cols:
#     823             raise ValueError(
# ...

# %%
data_un2.head(10000000000000000000000000000000000000000000000)

# %%
data_un2[data_un2['region_code']=="87"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-eba73718ae74> in <module>()
# ----> 1 data_un2[data_un2['region_code']=="87"].value_counts()
#
# NameError: name 'data_un2' is not defined

# %%
data4_5M = pd.read_csv('/content/drive/MyDrive/4_5_MA111.csv')

# %%
data4_5M.head()
# Out:
#    Unnamed: 0  Класс  Код_предмета      ЛогинОО  Балл_2019  Отметка_2019  \
# 0           0      4             2  sch01110001      11.83          3.97
# 1           1      4             2  sch01110003      13.37          4.06
# 2           2      4             2  sch01110004      12.90          4.22
# 3           3      4             2  sch01110005       9.61          3.43
# 4           4      4             2  sch01110006      12.77          4.23
#
#    Балл_%_2019  Отметка_%_2019  Балл_2020  Отметка_2020  Балл_%_2020  \
# 0        59.13           79.42      12.18          4.05        60.92
# 1        66.83           81.15      10.09          3.57        50.43
# 2        64.49           84.41       9.27          3.42        46.34
# 3        48.04           68.70       9.71          3.36        48.57
# 4        63.85           84.62       9.53          3.40        47.67
#
#    Отметка_%_2020  Дельта_Балл  Дельта_Балл_%  Дельта_Отметка  \
# ...

# %%
data4_5M['region_code'] = data4_5M['ЛогинОО'].apply(get_slice)

# %%
data4_5M.head()
# Out:
#    Unnamed: 0  Класс  Код_предмета      ЛогинОО  Балл_2019  Отметка_2019  \
# 0           0      4             2  sch01110001      11.83          3.97
# 1           1      4             2  sch01110003      13.37          4.06
# 2           2      4             2  sch01110004      12.90          4.22
# 3           3      4             2  sch01110005       9.61          3.43
# 4           4      4             2  sch01110006      12.77          4.23
#
#    Балл_%_2019  Отметка_%_2019  Балл_2020  Отметка_2020  Балл_%_2020  \
# 0        59.13           79.42      12.18          4.05        60.92
# 1        66.83           81.15      10.09          3.57        50.43
# 2        64.49           84.41       9.27          3.42        46.34
# 3        48.04           68.70       9.71          3.36        48.57
# 4        63.85           84.62       9.53          3.40        47.67
#
#    Отметка_%_2020  Дельта_Балл  Дельта_Балл_%  Дельта_Отметка  \
# ...

# %%
data4_5M[['region_code']] = data4_5M[['region_code']].apply(pd.to_numeric)

# %%
data4_5M_un = pd.merge(data4_5M, data_un____, on='region_code', how='inner')

# %%
# Сброс ограничений на количество выводимых рядов
#pd.set_option('display.max_rows', None)
 
# Сброс ограничений на число столбцов
#pd.set_option('display.max_columns', None)
 
# Сброс ограничений на количество символов в записи
#pd.set_option('display.max_colwidth', None)

# %%
data4_5M_un.head(10000000000000000000000000000000000)
# Out:
#        Unnamed: 0  Класс  Код_предмета      ЛогинОО  Балл_2019  Отметка_2019  \
# 0               0      4             2  sch01110001      11.83          3.97
# 1               1      4             2  sch01110003      13.37          4.06
# 2               2      4             2  sch01110004      12.90          4.22
# 3               3      4             2  sch01110005       9.61          3.43
# 4               4      4             2  sch01110006      12.77          4.23
# ...           ...    ...           ...          ...        ...           ...
# 32623       32623      4             2  sch92122004      13.62          4.15
# 32624       32624      4             2  sch92122007      13.38          4.31
# 32625       32625      4             2  sch92122008      11.64          3.88
# 32626       32626      4             2  sch92126001      14.07          4.45
# 32627       32627      4             2  sch92126007      11.86          3.95
#
# ...

# %%
print(data4_5M_un.isna().sum())
# Out:
# Unnamed: 0                                            0
# Класс                                                 0
# Код_предмета                                          0
# ЛогинОО                                               0
# Балл_2019                                             0
# Отметка_2019                                          0
# Балл_%_2019                                           0
# Отметка_%_2019                                        0
# Балл_2020                                             0
# Отметка_2020                                          0
# Балл_%_2020                                           0
# Отметка_%_2020                                        0
# Дельта_Балл                                           0
# Дельта_Балл_%                                         0
# Дельта_Отметка                                        0
# Дельта_Отметка_%                                      0
# region_code                                           0
# ...

# %%
data5_6M = pd.read_csv('/content/drive/MyDrive/5_6_MA111.csv')

# %%
data5_6M['region_code'] = data5_6M['ЛогинОО'].apply(get_slice)

# %%
data5_6M[['region_code']] = data5_6M[['region_code']].apply(pd.to_numeric)

# %%
data5_6M_un = pd.merge(data5_6M, data_un____, on='region_code', how='inner')

# %%
data5_6M_un.head()
# Out:
#    Unnamed: 0  Класс  Код_предмета      ЛогинОО  Балл_2019  Отметка_2019  \
# 0           0      5             2  sch01110001       8.91          3.26
# 1           1      5             2  sch01110003      10.53          3.61
# 2           2      5             2  sch01110004      11.59          3.73
# 3           3      5             2  sch01110005      11.73          3.80
# 4           4      5             2  sch01110006       7.67          3.08
#
#    Балл_%_2019  Отметка_%_2019  Балл_2020  Отметка_2020  ...  region_code  \
# 0        44.53           65.28       8.78          3.16  ...            1
# 1        52.63           72.11       9.90          3.49  ...            1
# 2        57.96           74.69       8.16          3.03  ...            1
# 3        58.67           76.00      10.68          3.55  ...            1
# 4        38.33           61.67      12.17          3.92  ...            1
#
#               названиерегиона       ввп  объекты  \
# ...

# %%
print(data5_6M_un.isna().sum())
# Out:
# Unnamed: 0                                            0
# Класс                                                 0
# Код_предмета                                          0
# ЛогинОО                                               0
# Балл_2019                                             0
# Отметка_2019                                          0
# Балл_%_2019                                           0
# Отметка_%_2019                                        0
# Балл_2020                                             0
# Отметка_2020                                          0
# Балл_%_2020                                           0
# Отметка_%_2020                                        0
# Дельта_Балл                                           0
# Дельта_Балл_%                                         0
# Дельта_Отметка                                        0
# Дельта_Отметка_%                                      0
# region_code                                           0
# ...

# %%
data4_5R = pd.read_csv('/content/drive/MyDrive/4_5_PY111.csv')

# %%
data4_5R['region_code'] = data4_5R['ЛогинОО'].apply(get_slice)

# %%
data4_5R[['region_code']] = data4_5R[['region_code']].apply(pd.to_numeric)

# %%
data4_5R_un = pd.merge(data4_5R, data_un____, on='region_code', how='inner')

# %%
data4_5R_un.head()
# Out:
#    Unnamed: 0  Класс  Код_предмета      ЛогинОО  Балл_2019  Отметка_2019  \
# 0           0      4             1  sch01110001      26.92          3.94
# 1           1      4             1  sch01110003      25.38          3.64
# 2           2      4             1  sch01110004      22.54          3.51
# 3           3      4             1  sch01110005      25.22          3.70
# 4           4      4             1  sch01110006      25.42          3.83
#
#    Балл_%_2019  Отметка_%_2019  Балл_2020  Отметка_2020  ...  region_code  \
# 0        70.85           78.77      23.15          3.59  ...            1
# 1        66.78           72.83      21.46          3.34  ...            1
# 2        59.31           70.15      19.34          3.22  ...            1
# 3        66.37           74.07      21.43          3.43  ...            1
# 4        66.89           76.67      18.17          3.08  ...            1
#
#               названиерегиона       ввп  объекты  \
# ...

# %%
print(data4_5R_un.isna().sum())
# Out:
# Unnamed: 0                                            0
# Класс                                                 0
# Код_предмета                                          0
# ЛогинОО                                               0
# Балл_2019                                             0
# Отметка_2019                                          0
# Балл_%_2019                                           0
# Отметка_%_2019                                        0
# Балл_2020                                             0
# Отметка_2020                                          0
# Балл_%_2020                                           0
# Отметка_%_2020                                        0
# Дельта_Балл                                           0
# Дельта_Балл_%                                         0
# Дельта_Отметка                                        0
# Дельта_Отметка_%                                      0
# region_code                                           0
# ...

# %%
data5_6R = pd.read_csv('/content/drive/MyDrive/5_6_PY.csv')

# %%
data5_6R['region_code'] = data5_6M['ЛогинОО'].apply(get_slice)

# %%
data5_6R[['region_code']] = data5_6R[['region_code']].apply(pd.to_numeric)

# %%
data5_6R_un = pd.merge(data5_6R, data_un____, on='region_code', how='inner')

# %%
data4_5M_un.to_csv("data4_5M_un(4).csv")
data5_6M_un.to_csv("data5_6M_un(4).csv")
data4_5R_un.to_csv("data4_5R_un(4).csv")
data5_6R_un.to_csv("data5_6R_un(4).csv")

# %%
from google.colab import files
files.download("data4_5M_un(4).csv")
files.download('data5_6R_un(4).csv')
files.download('data4_5R_un(4).csv')
files.download('data5_6M_un(4).csv')
